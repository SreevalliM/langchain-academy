# %% [markdown]
# # Fast Agent - Build a SQL Agent fast!
#
# ![LC_L1_Top.png](attachment:LC_L1_Top.png)

# %% [markdown]
# ## Setup

# %% [markdown]
# Load and/or check for needed environmental variables

# %%
import os, httpx
from dotenv import load_dotenv

# Load .env using absolute path (override=True to ensure it always loads fresh)
load_dotenv("/Users/L107127/Library/CloudStorage/OneDrive-EliLillyandCompany/Desktop/Foundation-Introduction-to-LangGraph---Python/.env", override=True)

CA_BUNDLE = "/Users/L107127/Library/CloudStorage/OneDrive-EliLillyandCompany/Desktop/Foundation-Introduction-to-LangGraph---Python/ca-bundle.pem"
os.environ["SSL_CERT_FILE"] = CA_BUNDLE
os.environ["REQUESTS_CA_BUNDLE"] = CA_BUNDLE

# Create a custom httpx client with the CA bundle
http_client = httpx.Client(verify=CA_BUNDLE)
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="llama-3.3-70b-versatile", temperature=0, http_client=http_client)

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///Chinook.db")

# %% [markdown]
# Define the runtime context to provide the agent and tools with access to the database.

# %%
from dataclasses import dataclass

from langchain_community.utilities import SQLDatabase


# define context structure to support dependency injection
@dataclass
class RuntimeContext:
    db: SQLDatabase

# %% [markdown]
# <b>⚠️ Security Note:</b> This demo does not include a filter on LLM-generated commands. In production, you would want to limit the scope of LLM-generated commands. ⚠️
# This tool will connect to the database. Note the use of `get_runtime` to access the graph **runtime context**.

# %%
from langchain_core.tools import tool
from langgraph.runtime import get_runtime

@tool
def execute_sql(query: str) -> str:
    """Execute a SQLite command and return results."""
    runtime = get_runtime(RuntimeContext)
    db = runtime.context.db

    try:
        return db.run(query)
    except Exception as e:
        return f"Error: {e}"

# %% [markdown]
# Add a system prompt to define your agents behavior.

# %%
SYSTEM_PROMPT = """You are a careful SQLite analyst.

Rules:
- Think step-by-step.
- When you need data, call the tool `execute_sql` with ONE SELECT query.
- Read-only only; no INSERT/UPDATE/DELETE/ALTER/DROP/CREATE/REPLACE/TRUNCATE.
- Limit to 5 rows of output unless the user explicitly asks otherwise.
- If the tool returns 'Error:', revise the SQL and try again.
- Prefer explicit column lists; avoid SELECT *.
"""

# %% [markdown]
# Create your agent! Add a model, tools, a prompt, and the runtime access, and go!  You can choose many agents from our [integrations](https://docs.langchain.com/oss/python/integrations/providers) list.

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=llm,
    tools=[execute_sql],
    system_prompt=SYSTEM_PROMPT,
    context_schema=RuntimeContext,
)

# %% [markdown]
# Here's a display of the agent ReAct Loop.

# %%
from IPython.display import Image, display

display(Image(agent.get_graph(xray=True).draw_mermaid_png()))

# %% [markdown]
# Run some queries. Notice:
# - The agent does not have the database schema and will need to discover it independently.
# - The agent may make mistakes! By returning error messages, the agent can self-correct its queries.
# - Notice you invoke the agent with `agent.stream`.
#     - This command and the `pretty_print` display the **messages** that communicate information between the model and the tools.
# - Notice the agent doesn't remember the schema between invocations... More on this later!

# %%
question = "Which table has the largest number of entries?"

for step in agent.stream(
    {"messages": question},
    context=RuntimeContext(db=db),
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Which table has the largest number of entries?
# ================================== Ai Message ==================================
# Tool Calls:
#   execute_sql (6yggk9az5)
#  Call ID: 6yggk9az5
#   Args:
#     query: SELECT tbl_name, COUNT(*) as count FROM sqlite_master WHERE type='table' GROUP BY tbl_name ORDER BY count DESC LIMIT 1;
# ================================= Tool Message =================================
# Name: execute_sql
#
# [('Track', 1)]
# ================================== Ai Message ==================================
# Tool Calls:
#   execute_sql (6jt0fcg4g)
#  Call ID: 6jt0fcg4g
#   Args:
#     query: SELECT name, rowid FROM sqlite_master WHERE type='table' ORDER BY rootpage DESC LIMIT 1;
# ================================= Tool Message =================================
# Name: execute_sql
#
# [('Track', 12)]
# ================================== Ai Message ==================================
# Tool Calls:
#   execute_sql (4rfahhpxg)
#  Call ID: 4rfahhpxg
#   Args:
#     query: SELECT name, rootpage FROM sqlite_master WHERE type='table' ORDER BY rootpage DESC LIMIT 1;
# ================================= Tool Message =================================
# Name: execute_sql
#
# [('Track', 13)]
# ================================== Ai Message ==================================
# Tool Calls:
#   execute_sql (ef1crx5gp)
#  Call ID: ef1crx5gp
#   Args:
#     query: SELECT name, (SELECT MAX(rowid) FROM sqlite_master) AS rowid FROM sqlite_master WHERE type='table' ORDER BY rowid DESC LIMIT 1;
# ================================= Tool Message =================================
# Name: execute_sql
#
# [('Album', 22)]
# ================================== Ai Message ==================================
# Tool Calls:
#   execute_sql (0vxs7k0xn)
#  Call ID: 0vxs7k0xn
#   Args:
#     query: SELECT name, (SELECT MAX(rowid) FROM sqlite_master) AS rowid FROM sqlite_master WHERE type='table' ORDER BY rowid DESC LIMIT 1;
# ================================= Tool Message =================================
# Name: execute_sql
#
# [('Album', 22)]
# ================================== Ai Message ==================================
# Tool Calls:
#   execute_sql (gsks5vcfj)
#  Call ID: gsks5vcfj
#   Args:
#     query: SELECT name, (SELECT MAX(rowid) FROM Album) AS rowid FROM Album LIMIT 1;
# ================================= Tool Message =================================
# Name: execute_sql
#
# Error: (sqlite3.OperationalError) no such column: name
# [SQL: SELECT name, (SELECT MAX(rowid) FROM Album) AS rowid FROM Album LIMIT 1;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ================================== Ai Message ==================================
# Tool Calls:
#   execute_sql (1t5dansxk)
#  Call ID: 1t5dansxk
#   Args:
#     query: SELECT COUNT(*) as count FROM Album;
# ================================= Tool Message =================================
# Name: execute_sql
#
# [(347,)]
# ================================== Ai Message ==================================
# Tool Calls:
#   execute_sql (tcxszm1a9)
#  Call ID: tcxszm1a9
#   Args:
#     query: SELECT COUNT(*) as count FROM Artist;
# ================================= Tool Message =================================
# Name: execute_sql
#
# [(275,)]
# ================================== Ai Message ==================================
# Tool Calls:
#   execute_sql (6wqazxtgs)
#  Call ID: 6wqazxtgs
#   Args:
#     query: SELECT COUNT(*) as count FROM Track;
# ================================= Tool Message =================================
# Name: execute_sql
#
# [(3503,)]
# ================================== Ai Message ==================================
#
# The table with the largest number of entries is the 'Track' table with 3503 entries.

# %%
question = "Which genre on average has the longest tracks?"

for step in agent.stream(
    {"messages": question},
    context=RuntimeContext(db=db),
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Which genre on average has the longest tracks?
# ================================== Ai Message ==================================
# Tool Calls:
#   execute_sql (8f0d320fn)
#  Call ID: 8f0d320fn
#   Args:
#     query: SELECT genre, AVG(duration) as avg_duration FROM tracks GROUP BY genre ORDER BY avg_duration DESC LIMIT 1;
# ================================= Tool Message =================================
# Name: execute_sql
#
# Error: (sqlite3.OperationalError) no such table: tracks
# [SQL: SELECT genre, AVG(duration) as avg_duration FROM tracks GROUP BY genre ORDER BY avg_duration DESC LIMIT 1;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ================================== Ai Message ==================================
# Tool Calls:
#   execute_sql (nxxh7tygq)
#  Call ID: nxxh7tygq
#   Args:
#     query: SELECT genre, AVG(duration) as avg_duration FROM genres GROUP BY genre ORDER BY avg_duration DESC LIMIT 1;
# ================================= Tool Message =================================
# Name: execute_sql
#
# Error: (sqlite3.OperationalError) no such table: genres
# [SQL: SELECT genre, AVG(duration) as avg_duration FROM genres GROUP BY genre ORDER BY avg_duration DESC LIMIT 1;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ================================== Ai Message ==================================
# Tool Calls:
#   execute_sql (zk1n5a75v)
#  Call ID: zk1n5a75v
#   Args:
#     query: SELECT name, AVG(duration) as avg_duration FROM genres JOIN tracks ON genres.id = tracks.genre_id GROUP BY name ORDER BY avg_duration DESC LIMIT 1;
# ================================= Tool Message =================================
# Name: execute_sql
#
# Error: (sqlite3.OperationalError) no such table: genres
# [SQL: SELECT name, AVG(duration) as avg_duration FROM genres JOIN tracks ON genres.id = tracks.genre_id GROUP BY name ORDER BY avg_duration DESC LIMIT 1;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ================================== Ai Message ==================================
# Tool Calls:
#   execute_sql (01ecgx6hb)
#  Call ID: 01ecgx6hb
#   Args:
#     query: SELECT T2.name, AVG(T1.duration) as avg_duration FROM tracks AS T1 JOIN genres AS T2 ON T1.genre_id = T2.id GROUP BY T2.name ORDER BY avg_duration DESC LIMIT 1;
# ================================= Tool Message =================================
# Name: execute_sql
#
# Error: (sqlite3.OperationalError) no such table: tracks
# [SQL: SELECT T2.name, AVG(T1.duration) as avg_duration FROM tracks AS T1 JOIN genres AS T2 ON T1.genre_id = T2.id GROUP BY T2.name ORDER BY avg_duration DESC LIMIT 1;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ================================== Ai Message ==================================
# Tool Calls:
#   execute_sql (2gzajasys)
#  Call ID: 2gzajasys
#   Args:
#     query: SELECT T2.name, AVG(T1.duration) as avg_duration FROM genres AS T2 JOIN tracks AS T1 ON T2.id = T1.genre_id GROUP BY T2.name ORDER BY avg_duration DESC LIMIT 1;
# ================================= Tool Message =================================
# Name: execute_sql
#
# Error: (sqlite3.OperationalError) no such table: genres
# [SQL: SELECT T2.name, AVG(T1.duration) as avg_duration FROM genres AS T2 JOIN tracks AS T1 ON T2.id = T1.genre_id GROUP BY T2.name ORDER BY avg_duration DESC LIMIT 1;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ================================== Ai Message ==================================
#
# I'm unable to fulfill this request as the necessary tables do not exist in the database.

# %%
question = "Please list all of the tables"

for step in agent.stream(
    {"messages": question},
    context={"db": db},
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Please list all of the tables
# ================================== Ai Message ==================================
# Tool Calls:
#   execute_sql (call_l1UWwgSfPDbtNMgiOqdd1QHf)
#  Call ID: call_l1UWwgSfPDbtNMgiOqdd1QHf
#   Args:
#     query: SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%' ORDER BY name LIMIT 5;
# ================================= Tool Message =================================
# Name: execute_sql
#
# [('Album',), ('Artist',), ('Customer',), ('Employee',), ('Genre',)]
# ================================== Ai Message ==================================
# Tool Calls:
#   execute_sql (call_XVZ2quL9z2LYrw1gb6jknw5L)
#  Call ID: call_XVZ2quL9z2LYrw1gb6jknw5L
#   Args:
#     query: SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%' ORDER BY name;
# ================================= Tool Message =================================
# Name: execute_sql
#
# [('Album',), ('Artist',), ('Customer',), ('Employee',), ('Genre',), ('Invoice',), ('InvoiceLine',), ('MediaType',), ('Playlist',), ('PlaylistTrack',), ('Track',)]
# ================================== Ai Message ==================================
#
# There are 11 tables:
#
# - Album
# - Artist
# - Customer
# - Employee
# - Genre
# - Invoice
# - InvoiceLine
# - MediaType
# - Playlist
# - PlaylistTrack
# - Track

# %% [markdown]
# **Create your own query here!**  Add some questions of your own.

# %%
question = "TRY YOUR OWN QUERY HERE"

for step in agent.stream(
    {"messages": question},
    context={"db": db},
    stream_mode="values",
):
    step["messages"][-1].pretty_print()

# %% [markdown]
# ### Let's try this Studio
